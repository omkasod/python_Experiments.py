# %% [markdown]
# <a href="https://colab.research.google.com/github/omkasod/python_Experiments.py/blob/main/Expt_3_Om.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:- Om Gajanan Kasod
#
# Roll No.:- RA2202
#
# Class & Division:- SY-B.tech (B1)

# %% [markdown]
# # Experiment No.03

# %% [markdown]
# Case Studies
#
# Case Study 1: IF Statement (5 Programs)

# %%
# Program 1: Robot alert when obstacle is very close

# Taking input from user
distance = float(input("Enter distance from obstacle (in cm): "))

# Checking condition
if distance < 10:
  print(" Alert! Obstacle is very close.")

print("Program executed successfully.")
# Out:
# Enter distance from obstacle (in cm): 50
# Program executed successfully.

# %%
# Program 2: Conveyor overload protection system

load = float(input("Enter current load (in kg): "))

if load > 100:
  print(" Overload detected! Stopping conveyor.")

  print("System check complete.")
# Out:
# Enter current load (in kg): 200
#  Overload detected! Stopping conveyor.
# System check complete.

# %%
# Program 3: Temperature-based cooling system

temperature = float(input("Enter temperature (В°C): "))

if temperature > 50:
  print("High temperature! Cooling system activated.")

  print("Monitoring done.")
# Out:
# Enter temperature (В°C): 85
# High temperature! Cooling system activated.
# Monitoring done.

# %%
# Program 4: Object detection system

object_detected=input("Is object detected? (yes/no): ")

if object_detected.lower() == "yes":
  print(" Picking up the object.")

  print("Task completed.")
# Out:
# Is object detected? (yes/no): yes
#  Picking up the object.
# Task completed.

# %%
# Program 5: Battery level monitoring

battery = int(input("Enter battery percentage: "))
if battery < 20:
  print("Low battery! Please recharge.")

print("Battery check done.")
# Out:
# Enter battery percentage: 58
# Battery check done.

# %% [markdown]
# Case Study 2: IF Else Statement (5 Programs)

# %%
#### Program 1: Warehouse robot navigation
obstacle = input("Is obstacle detected? (yes/no): ")

if obstacle.lower()=="yes":
  print("Obstacle detected! Changing path.")
else:
  print("Path clear. Moving forward.")
# Out:
# Is obstacle detected? (yes/no): no
# Path clear. Moving forward.

# %%
# Program 2: Smart car decision system
obstacle=input("Obstacle detected? (yes/no): ")

if obstacle.lower()=="yes":
  print("Car stopped.")

else:
  print("Car is moving.")
# Out:
# Obstacle detected? (yes/no): yes
# Car stopped.

# %%
# Program 3: Automatic plant watering system

moisture=int(input("Enter soil moisture level (%): "))

if moisture < 30:
  print(" Soil dry. Watering plants.")

else:
  print("Moisture sufficient. No watering needed.")
# Out:
# Enter soil moisture level (%): 52
# Moisture sufficient. No watering needed.

# %%
 # Program 4: Robotic arm pick and place

object_detected=input("Object detected? (yes/no): ")

if object_detected.lower()=="yes":
  print("Picking and placing object.")

else:
  print("No object found.")
# Out:
# Object detected? (yes/no): yes
# Picking and placing object.

# %%
 # Program 5: Fire detection system

fire = input("Fire detected? (yes/no): ")

if fire.lower()=="yes":
  print("Fire detected! Activating extinguisher.")

else:
  print("No fire detected. System normal.")
# Out:
# Fire detected? (yes/no): yes
# Fire detected! Activating extinguisher.

# %% [markdown]
# Case Study 3: ELIF Statement (5 Programs)

# %%
#Program 1: Check Grade Using

marks = int(input("Enter marks: "))

if marks >= 90:
  print("Grade A")

elif marks>=75:
  print("Grade B")

elif marks>=50:
  print("Grade C")

else:
  print("Fail")
# Out:
# Enter marks: 76
# Grade B

# %%
#Program 2: Find Largest of Three Numbers

a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter third number: "))

if a > b and a > c:
  print("Largest number is:",a)

elif b > c:
  print("Largest number is:",b)

else:
  print("Largest number is:",c)
# Out:
# Enter first number: 10
# Enter second number: 50
# Enter third number: 30
# Largest number is: 50

# %%
#Program 3: Check Vowel or Consonant

ch=input("Enter a character: ")

if ch in"aeiouAEIOU":
  print("It is a vowel")

elif ch.isalpha():
  print("It is a consonant")

else:
  print("Invalid input")
# Out:
# Enter a character: a
# It is a vowel

# %%
#Program 4: Simple Calculator Using elif

num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
op=input("Enter operator (+, -, *, /): ")

if op=="+":
  print("Result:",num1+num2)

elif op=="-":
  print("Result:",num1-num2)

elif op=="*":
  print("Result:",num1*num2)

elif op=="/":
  print("Result:",num1/num2)

else:
  print("Invalid operator")
# Out:
# Enter first number: 10
# Enter second number: 30
# Enter operator (+, -, *, /): +
# Result: 40

# %%
 #Program 5: Check Age Category

age = int(input("Enter your age: "))

if age < 13:
  print("Child")

elif age < 20:
  print("Teenager")

elif age < 60:
  print("Adult")

else:
  print("Senior Citizen")
# Out:
# Enter your age: 20
# Adult

# %% [markdown]
# Case Study 4: Nested Statement (5 Programs)

# %%
#Program 1: Check Positive and Even Number

num=int(input("Enter a number: "))

if num > 0:
  if num % 2 == 0:
    print("Positive Even Number")
  else:
    print("Positive Odd Number")
else:
  print("Negative Number")
# Out:
# Enter a number: 55
# Positive Odd Number

# %%
#Program 2: Check Eligibility for Exam

attendance=int(input("Enter attendance percentage: "))
medical=input("Medical cause? (yes/no): ")

if attendance >= 75:
  print("Allowed to sit in exam")

else:
  if medical=="yes":
    print("Allowed due to medical reason")

  else:
    print("Not allowed in exam")
# Out:
# Enter attendance percentage: 98
# Medical cause? (yes/no): yes
# Allowed to sit in exam

# %%
#Program 3: Login System
username=input("Enter username: ")
password=input("Enter password: ")

if username=="admin":

  if password=="1234":
    print("Login Successful")
  else:
    print("Wrong Password")

else:
  print("Invalid Username")
# Out:
# Enter username: om
# Enter password: 1254
# Invalid Username

# %%
#Program 4: Check Largest Among Three Numbers

a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter third number: "))

if a > b:
  if a > c:
    print("Largest number is:",a)
  else:
    print("Largest number is:",c)

else:
  if b > c:
    print("Largest number is:",b)
  else:
    print("Largest number is:",c)
# Out:
# Enter first number: 20
# Enter second number: 60
# Enter third number: 200
# Largest number is: 200

# %%
#Program 5: Banking Withdrawal System

balance = 5000
amount=int(input("Enter withdrawal amount: "))

if amount <= balance:

  if amount % 100 == 0:
    print("Please collect your cash")
  else:
    print("Amount should be multiple of 100")

else:
  print("Insufficient Balance")
# Out:
# Enter withdrawal amount: 5000
# Please collect your cash
