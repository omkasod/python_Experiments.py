# %% [markdown]
# <a href="https://colab.research.google.com/github/omkasod/python_Experiments.py/blob/main/Expt_10_Om.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:- Om Gajanan Kasod
#
# Roll Number:- RA2202
#
# Class & Division:- SY-B.Tech (B1)

# %% [markdown]
# # Experiment No.10

# %% [markdown]
# Case Study

# %%
# Python program for directional decisions
direction = input("Enter direction (left/right/forward/backward): ")
if direction == "left":
  print("Moving Left")
# 12/05/2026, 22:34 Exp.No.10: Conditional Stat - Colab
# https://colab.research.google.com/drive/150vU4FKZmYNRVA6LpvnPoSqlrhvRocuc 1/2

elif direction == "right":
  print("Moving Right")
elif direction == "forward":
  print("Moving Forward")
elif direction == "backward":
  print("Moving Backward")
else:
  print("Invalid Direction")
# Out:
# Enter direction (left/right/forward/backward): left
# Moving Left
