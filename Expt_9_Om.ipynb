# %% [markdown]
# Name:- Om Gajanan Kasod
#
# Roll Number:- RA2202
#
# Class & Division:- SY-B.Tech (B1)

# %% [markdown]
# # Experiment No.09

# %% [markdown]
# Case Studies
#
# Case Study 1: Simple delay

# %%
import time
print("Program started")
time.sleep(3)
print("3 seconds completed")
# Out:
# Program started
# 3 seconds completed

# %% [markdown]
# Detailed Examples

# %%
import time
print("Countdown begins")
for i in range(5,0,-1):
  print(i)
  time.sleep(2)
print("Time's up!")
# Out:
# Countdown begins
# 5
# 4
# 3
# 2
# 1
# Time's up!

# %% [markdown]
# Case Study 2: Loading Animation

# %%
import time
print("Loading",end="")
for i in range(5):
  print(".",end="")
  time.sleep(1)
print("\nCompleted!")
# Out:
# Loading.....
# Completed!

# %% [markdown]
# Case Study 3: Story Narration Delay

# %%
import time
print("Once upon a time...")
time.sleep(2)
print("There was a Python programmer.")
time.sleep(2)
print("Who loved automation!")
# Out:
# Once upon a time...
# There was a Python programmer.
# Who loved automation!

# %% [markdown]
# Case Study 4: Traffic Signal Simulation

# %%
import time
print("Red Light")
time.sleep(3)
print("Yellow Light")
time.sleep(2)
print("Green Light")
time.sleep(3)
# Out:
# Red Light
# Yellow Light
# Green Light

# %% [markdown]
# Case Study 5: Digital Clock Display

# %%
import time
for i in range(1,6):
  print("Second:",i)
  time.sleep(1)
# Out:
# Second: 1
# Second: 2
# Second: 3
# Second: 4
# Second: 5

# %% [markdown]
# Case Study 6

# %%
import time
print("Welcome to Python Delay Demo")
time.sleep(2)
print("Starting process...")
time.sleep(1)
for i in range(3):
  print("Processing step",i+1)
  time.sleep(2)
print("Task Completed Successfully!")
# Out:
# Welcome to Python Delay Demo
# Starting process...
# Processing step 1
# Processing step 2
# Processing step 3
# Task Completed Successfully!
