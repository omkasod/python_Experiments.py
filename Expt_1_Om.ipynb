# %% [markdown]
# <a href="https://colab.research.google.com/github/omkasod/python_Experiments.py/blob/main/Expt_1_Om.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:- Om Gajanan Kasod
#
# Roll Number:- RA2202
#
# Class & Division:- SY-B.Tech (B1)

# %% [markdown]
# # Experiment No.01

# %% [markdown]
# Case Studies

# %%
print("Welcome to Python Programming")
print("I am learning Python")

for i in range(2):
  print("Keep Coding!")

  print(10 + 5)

  print("Good Morning")
# Out:
# Welcome to Python Programming
# I am learning Python
# Keep Coding!
# 15
# Good Morning
# Keep Coding!
# 15
# Good Morning
