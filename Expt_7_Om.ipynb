# %% [markdown]
# Name:- Om Gajanan Kasod
#
# Roll Number:- RA2202
#
# Class & Division:- SY-B.Tech (B1)

# %% [markdown]
# **Experiment** No.07

# %% [markdown]
# Case Studies
#
# Case Study 1: Creating a Dictionar

# %%
a={1:'Zeal',2:'Engineering',3:'College'}
print(a)
b=dict(a="Zeal",b="Engineering",c="College")
print(b)
# Out:
# {1: 'Zeal', 2: 'Engineering', 3: 'College'}
# {'a': 'Zeal', 'b': 'Engineering', 'c': 'College'}

# %% [markdown]
# Case Study 2: Accessing Dictionary Items

# %%
d={"name":"MSD",1:"Python",(1,2):[1,2,4]}
# Access using key
print(d["name"])
# Access using get()
print(d.get("name"))
# Out:
# MSD
# MSD

# %% [markdown]
# Case Study 3: Adding and Updating Dictionary Items

# %%
d={1:'Zeal',2:'College of',3:'Engineering'}

# Adding a new key-value pair
d["Established in"]=1980

# Updating an existing value
d[1]="Imperial"
print(d)
# Out:
# {1: 'Imperial', 2: 'College of', 3: 'Engineering', 'Established in': 1980}

# %% [markdown]
# Case Study 4: Removing Dictionary Items

# %%
d={1:'Zeal',2:'Engineering',3:'College','Established in':2008}
print(d)

# Using del
del d["Established in"]
print(d)

# Using pop()
val=d.pop(1)
print(val)

# Using popitem()
key,val=d.popitem()
print(f"Key: {key}, Value: {val}")

# Using clear()
d.clear()
print(d)
# Out:
# {1: 'Zeal', 2: 'Engineering', 3: 'College', 'Established in': 2008}
# {1: 'Zeal', 2: 'Engineering', 3: 'College'}
# Zeal
# Key: 3, Value: College
# {}

# %% [markdown]
# Case Study 5: Iterating Through a Dictionary

# %%
d={1:'Zeal',2:'Engineering','Established in':2008}

# Iterate over keys
for key in d:
  print(key)

# Iterate over values
for value in d.values():
  print(value)

# Iterate over key-value pairs
for key,value in d.items():
  print(f"{key}: {value}")
# Out:
# 1
# 2
# Established in
# Zeal
# Engineering
# 2008
# 1: Zeal
# 2: Engineering
# Established in: 2008

# %% [markdown]
# Case Study 6: Nested Dictionaries

# %%
d={1:'MAHI',2:'For',3:{'A':'Welcome','B':'To','C':'MAHI'}}
print(d)
# Out:
# {1: 'Geeks', 2: 'For', 3: {'A': 'Welcome', 'B': 'To', 'C': 'Geeks'}}

# %% [markdown]
# Case Study 7: Student Record System

# %%
students={
101:{"name":"Mahi","marks":85},
102:{"name":"Virat","marks":90},
103:{"name":"Rohit","marks":78}
}

# Access student details
print(students[101]["name"])

# Add new student
students[104]={"name":"Priya","marks":88}

# Update marks
students[102]["marks"]=95

# Display all students
for roll,details in students.items():
  print(roll,details)
# Out:
# Mahi
# 101 {'name': 'Mahi', 'marks': 85}
# 102 {'name': 'Virat', 'marks': 95}
# 103 {'name': 'Rohit', 'marks': 78}
# 104 {'name': 'Priya', 'marks': 88}

# %% [markdown]
# Case Study 8: Word Frequency Counter

# %%
text = "apple banana apple mango banana apple"
words = text.split()
frequency = {}
for word in words:
  if word in frequency:
    frequency[word] += 1
  else:
    frequency[word] = 1
print(frequency)
# Out:
# {'apple': 3, 'banana': 2, 'mango': 1}

# %% [markdown]
# Case Study 9: Product Price Lookup

# %%
products = {
"laptop": 50000,
"mobile": 20000,
"tablet": 15000
}
item = input("Enter product name: ")
if item in products:
  print("Price:", products[item])
else:
  print("Product not found")
# Out:
# Enter product name: mobile
# Price: 20000
